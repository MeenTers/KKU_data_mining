# %% [markdown]
# <a href="https://colab.research.google.com/github/MeenTers/KKU_data_mining/blob/master/Classification(Decision_Tree).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets

# %%
iris_data = datasets.load_iris()
X = iris_data['data']
y = iris_data['target']

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# ![decision.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Import

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Define

# %%
myTree = DecisionTreeClassifier(criterion='entropy',max_depth=2)

# %% [markdown]
# ### Train

# %%
myTree.fit(X[:-2,:], y[:-2])
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# ### Test

# %%
myTree.predict(X[-2:,:])
# Out:
# array([2, 2])

# %% [markdown]
# ## Draw Tree

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(myTree)
# Out:
# [Text(133.92000000000002, 181.2, 'X[2] <= 2.45\nentropy = 1.585\nsamples = 148\nvalue = [50, 50, 48]'),
#  Text(66.96000000000001, 108.72, 'entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(200.88000000000002, 108.72, 'X[3] <= 1.75\nentropy = 1.0\nsamples = 98\nvalue = [0, 50, 48]'),
#  Text(133.92000000000002, 36.23999999999998, 'entropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(267.84000000000003, 36.23999999999998, 'entropy = 0.156\nsamples = 44\nvalue = [0, 1, 43]')]

# %%
X[-2:]
# Out:
# array([[6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])
