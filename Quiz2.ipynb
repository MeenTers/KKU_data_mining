# %% [markdown]
# <a href="https://colab.research.google.com/github/MeenTers/KKU_data_mining/blob/master/Quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/data_viz'

# %%
province_path = os.path.join(path,'3.-41-58.xls')

# %%
province_df = pd.read_excel(province_path)
province_df
# Out:
#    รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ...          Unnamed: 12
# 0   Average Monthly Income Per Household: 1998 - 2015                        ...                  NaN
# 1                                                 NaN                        ...         บาท   Baht
# 2                                      ภาค และจังหวัด                        ...  Region and province
# 3                                                 NaN                        ...                  NaN
# 4                                                 NaN                        ...                  NaN
# ..                                                ...                        ...                  ...
# 87                                           นราธิวาส                        ...           Narathiwat
# 88                                                NaN                        ...                  NaN
# ...

# %%
province_df.drop([0,1,5,6,11,34,52,90,91])
# Out:
#    รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ...          Unnamed: 12
# 2                                      ภาค และจังหวัด                        ...  Region and province
# 3                                                 NaN                        ...                  NaN
# 4                                                 NaN                        ...                  NaN
# 7                                       กรุงเทพมหานคร                        ...              Bangkok
# 8                                         สมุทรปราการ                        ...         Samut Prakan
# ..                                                ...                        ...                  ...
# 85                                            ปัตตานี                        ...              Pattani
# 86                                               ยะลา                        ...                 Yala
# ...

# %%
# Out:
#    รายได้เฉลี่ยต่อเดือนต่อครัวเรือน จำแนกตามภาค และจังหวัด พ.ศ. 2541 - 2558  ...              Unnamed: 12
# 51                                          เพชรบูรณ์                        ...               Phetchabun
# 52                              ภาคตะวันออกเฉียงเหนือ                        ...      Northeastern Region
# 53                                         นครราชสีมา                        ...        Nakhon Ratchasima
# 54                                          บุรีรัมย์                        ...                 Buri Ram
# 55                                           สุรินทร์                        ...                    Surin
# 56                                           ศรีสะเกษ                        ...                Si Sa Ket
# 57                                        อุบลราชธานี                        ...         Ubon Ratchathani
# 58                                              ยโสธร                        ...                 Yasothon
# ...
