# %% [markdown]
# <a href="https://colab.research.google.com/github/MeenTers/KKU_data_mining/blob/master/Data102.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# os for ทำงานเกี่ยวกับไฟล์
import os
# pd เพื่อเรียกใช้ตาราง ในไฟล์
import pandas as pd
# สร้างตัวแปลในชื่อ base_path path คือที่ที่เก็บข้อมูลของเราเอง
base_path = '/content/drive/My Drive/DWDM_material'
# เรียกใช้ไฟล์ในโฟเดอร์
data = pd.read_csv(os.path.join(base_path,'test.csv'))
# show เเค่หัวตาราง
data.head()
# Out:
#    Unnamed: 0        x        y
# 0           0  55.3846  97.1795
# 1           1  51.5385  96.0256
# 2           2  46.1538  94.4872
# 3           3  42.8205  91.4103
# 4           4  40.7692  88.3333

# %%
data.describe()
# Out:
#        Unnamed: 0           x           y
# count  142.000000  142.000000  142.000000
# mean    70.500000   54.263273   47.832253
# std     41.135953   16.765142   26.935403
# min      0.000000   22.307700    2.948700
# 25%     35.250000   44.102600   25.288450
# 50%     70.500000   53.333300   46.025600
# 75%    105.750000   64.743600   68.525675
# max    141.000000   98.205100   99.487200

# %% [markdown]
# ## Box plot

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['x'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd8774cd5c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd8774cdfd0>,
#   <matplotlib.lines.Line2D at 0x7fd877462390>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd877462a90>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd877462710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd8774cd8d0>,
#   <matplotlib.lines.Line2D at 0x7fd8774cdc50>]}

# %%
plt.boxplot(data['x'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd876fa0ba8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd876fae5f8>,
#   <matplotlib.lines.Line2D at 0x7fd876fae978>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd876fba0b8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd876faecf8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd876fa0eb8>,
#   <matplotlib.lines.Line2D at 0x7fd876fae278>]}

# %%
plt.boxplot(data['x'],vert=False,whis=1.2)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd877438160>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd876fbc080>,
#   <matplotlib.lines.Line2D at 0x7fd8774525f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd876f61080>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd876f5ceb8>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd877438668>,
#   <matplotlib.lines.Line2D at 0x7fd876fba400>]}

# %%
oput = plt.boxplot(data['x'],vert=False,whis=1.2)

# %%
oput['fliers'][0].get_xdata()
# Out:
# array([93.3333, 95.3846, 98.2051, 91.2821])

# %%
oput['whiskers'][0].get_xdata()
# Out:
# array([44.1026, 22.3077])

# %%
oput['whiskers'][1].get_xdata()
# Out:
# array([64.7436, 89.4872])

# %% [markdown]
# ## Scatter plot

# %%
plt.scatter(data['x'],data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'])

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='g')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='g',marker='*')

# %%
plt.scatter(data['x'],data['y'],s=data['y'],c='g',marker='*',alpha=0.4)
plt.scatter([44,42,50],[15,14,80],s=250,alpha=0.6)

# %% [markdown]
# HW ให้วาดปีกไดโนเสาร์และงาไดโนเสาร์

# %%
plt.scatter(data['x'],data['y'])
plt.scatter([75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,90,90,90,90,90,90,90,90,90,90,90,90,90,89.8,89.5,89.4,89.3,89.2,89.1,89,88.9,88.8,88.7,88.6,88.5,88.4,88.3,88.2,88.1,88,87.9,87.8,87.7,87.6,87.5,87.4,87.3,87.2,87.1,87,86.9,86.8,86.7,30,29.9,29.8,29.7,29.6,29.5,29.4,29.3,29.2,29.1,29,28.9,28.8,28.7,28.6,28.5,28.4,28.3,28.2,28.1,28,27.9,27.8,27.7,27.6,27.5,27.5,27.6,27.7,27.8,27.9],[80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,95,93,92,91,90,89,88,87,86,85,84,83,82,81,80,79,78,77,76,75,74,73,72,71,70,69,68,67,66,65,64,63,62,61,60,59,58,57,56,55,54,53,52,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92],marker= '*',c = 'r')
